# %% [markdown]
# # ***HW1-report seaborn***

# %% [markdown]
# ### *project link*

# %% [markdown]
# https://github.com/mwaskom/seaborn

# %% [markdown]
# ## Table of Contents
# - [What is Seaborn?](#what-is-seaborn)
# - [Example plot](#example-plot)
# - [Key takeaways](#key-takeaways)

# %% [markdown]
# ## What is Seaborn

# %% [markdown]
# - Seaborn is a Python *visualization library*.
# - It works well with pandas DataFrames.
# - It builds on **matplotlib**.

# %%
##

# %% [markdown]
# ![Screenshot 2026-02-07 at 17.51.07.png](attachment:15f62d67-fbe2-4ecd-acac-2281ef5645c4.png)
